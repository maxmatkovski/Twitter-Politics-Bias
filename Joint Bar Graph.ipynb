# %%
import numpy as np 
import matplotlib.pyplot as plt

values = [1,2,3,4,5]
republicans = [547, 90, 134, 75, 155]
democrats = [572, 82, 129, 75, 143]

X_axis = np.arange(len(values))
  
plt.bar(X_axis - 0.2, republicans, 0.4, label = 'Republicans', color='red')
plt.bar(X_axis + 0.2, democrats, 0.4, label = 'Democrats')
  
plt.xticks(X_axis, values)
plt.xlabel("Sentiment Score")
plt.ylabel("Tweet Counts")
plt.title("Republican vs Democrat Twitter Sentiment Distribution")
plt.legend()
plt.show()
